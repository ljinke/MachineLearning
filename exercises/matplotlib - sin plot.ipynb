# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import pi

x = np.arange(0, 2*pi, 0.1);
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.linspace( 0, 2*pi, 100 ) 
y = np.cos(x)

plt.plot(x, y)
plt.show()
