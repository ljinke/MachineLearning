# %% [markdown]
# # TensorFlow 示例

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# 使用 NumPy 生成假数据(phony data), 总共 100 个点

# %%
x_data = np.float32(np.random.rand(2, 100)) # 随机输入
y_data = np.dot([0.100, 0.200], x_data) + 0.300

# %%
print (x_data)
print (y_data)
import matplotlib.pyplot as plt
plt.plot(x_data[0], x_data[1])
plt.plot(y_data[0], y_data[1])
# Out:
# [[ 0.69955093  0.96452069  0.81410027  0.08824307  0.07868648  0.5897997
#    0.99904507  0.38461146  0.28479165  0.8366642   0.24025296  0.34127706
#    0.78899562  0.93034691  0.86516523  0.03800863  0.26893046  0.87693262
#    0.22723378  0.12837304  0.85988492  0.78031242  0.72750401  0.99852258
#    0.92429996  0.44811276  0.09656604  0.38627002  0.31365123  0.61916476
#    0.61118376  0.03185291  0.63634557  0.72951776  0.74957871  0.37829739
#    0.90211743  0.96947372  0.5518105   0.51435369  0.65701133  0.52700222
#    0.48538816  0.85526752  0.77069205  0.56399846  0.94133741  0.32922104
#    0.24274746  0.55192721  0.88770533  0.16427889  0.28973952  0.77724212
#    0.50238258  0.70915473  0.41198993  0.49916673  0.53632605  0.26249826
#    0.32807964  0.30245671  0.93769175  0.19082195  0.02317742  0.45895216
#    0.11400592  0.63353193  0.22152577  0.1688318   0.85764766  0.55039418
#    0.00685387  0.2594035   0.81019849  0.39290136  0.38632822  0.95520383
#    0.38031614  0.03869883  0.91813254  0.69116622  0.89830416  0.88290727
#    0.8296026   0.905882    0.17224301  0.6784485   0.03544575  0.08644723
#    0.67938364  0.88891912  0.67486459  0.89300954  0.49053988  0.75453645
#    0.84090316  0.17611484  0.19220097  0.61108547]
#  [ 0.68665779  0.42705914  0.46691814  0.71044052  0.49342066  0.49509627
#    0.81142902  0.06021376  0.42223799  0.34853265  0.17133896  0.01721294
#    0.9467302   0.71525753  0.87320626  0.25983915  0.3654632   0.90345502
#    0.86642301  0.657157    0.1650987   0.60122997  0.41961637  0.0825391
#    0.5338918   0.195609    0.139479    0.83903527  0.93569785  0.83533663
#    0.38314521  0.33105224  0.09755103  0.8173309   0.41048113  0.74406707
#    0.53996032  0.20832823  0.5541985   0.14185962  0.00879045  0.70945817
#    0.78538203  0.17002313  0.74813497  0.22639862  0.26954657  0.13477898
#    0.93919206  0.52745438  0.22658022  0.5981065   0.48828372  0.53553116
#    0.52422553  0.12580888  0.88313204  0.25241435  0.92926121  0.90850139
#    0.34051248  0.76379162  0.84973222  0.78547055  0.02164477  0.32446176
#    0.42974767  0.55168843  0.11356176  0.61888278  0.12278554  0.20169218
#    0.18328203  0.18717545  0.28014657  0.99069154  0.18706293  0.28407797
#    0.71234882  0.37857988  0.07949644  0.4380497   0.00103409  0.51567525
#    0.00207136  0.88422215  0.15955174  0.17190152  0.74150455  0.32750806
#    0.29099002  0.98107278  0.26680869  0.34576499  0.16502567  0.66429883
#    0.03831847  0.9600473   0.17836803  0.96924037]]
# [ 0.50728665  0.4818639   0.47479365  0.45091241  0.40655278  0.45799922
#   0.56219031  0.3505039   0.41292676  0.45337295  0.35829309  0.33757029
#   0.5682456   0.5360862   0.56115777  0.35576869  0.39998569  0.56838427
#   0.49600798  0.4442687   0.41900823  0.49827724  0.45667368  0.41636008
#   0.49920835  0.38393308  0.3375524   0.50643406  0.51850469  0.5289838
#   0.43774742  0.36939574  0.38314476  0.53641796  0.4570541   0.48664315
#   0.49820381  0.43861302  0.46602075  0.37980729  0.36745922  0.49459186
#   0.50561522  0.41953138  0.5266962   0.40167957  0.44804305  0.3598779
#   0.51211316  0.4606836   0.43408658  0.43604919  0.4266307   0.48483045
#   0.45508336  0.39607725  0.5178254   0.40039954  0.53948485  0.5079501
#   0.40091046  0.48300399  0.56371562  0.4761763   0.3066467   0.41078757
#   0.39735013  0.47369088  0.34486493  0.44065973  0.41032187  0.39537785
#   0.33734179  0.36337544  0.43704916  0.53742844  0.37604541  0.45233598
#   0.48050138  0.37958586  0.40771254  0.45672656  0.39003723  0.49142578
#   0.38337453  0.56743263  0.34913465  0.40222515  0.45184548  0.37414634
#   0.42613637  0.58510647  0.4208482   0.45845395  0.38205912  0.50831341
#   0.39175401  0.50962095  0.3548937   0.55495662]

# %% [markdown]
# 构造一个线性模型

# %%
b = tf.Variable(tf.zeros([1]))
W = tf.Variable(tf.random_uniform([1, 2], -1.0, 1.0))
y = tf.matmul(W, x_data) + b

# %% [markdown]
# 最小化方差

# %%
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %% [markdown]
# 初始化变量

# %%
init = tf.initialize_all_variables()

# %% [markdown]
# 启动图 (graph)

# %%
sess = tf.Session()
sess.run(init)

# %% [markdown]
# 拟合平面

# %%
for step in xrange(0, 201):
    sess.run(train)
    if step % 20 == 0:
        print step, sess.run(W), sess.run(b)
# Out:
# 0 [[-0.01336417  0.61925501]] [ 0.34652162]
# 20 [[ 0.08423396  0.26651794]] [ 0.2764954]
# 40 [[ 0.10143103  0.21368428]] [ 0.29249167]
# 60 [[ 0.10144067  0.20319237]] [ 0.29761556]
# 80 [[ 0.10060748  0.20083402]] [ 0.29924491]
# 100 [[ 0.10021538  0.20023656]] [ 0.29976121]
# 120 [[ 0.10007166  0.20007059]] [ 0.29992449]
# 140 [[ 0.1000232   0.20002165]] [ 0.29997614]
# 160 [[ 0.1000074   0.20000677]] [ 0.29999244]
# 180 [[ 0.10000234  0.20000213]] [ 0.29999763]
# 200 [[ 0.10000074  0.20000067]] [ 0.29999924]
